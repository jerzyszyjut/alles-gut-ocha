# %%
import pandas as pd

from pathlib import Path

files = Path("../../data").glob("*.csv")

for file in files:
    df = pd.read_csv(file)
    print(f"{file} {df.columns}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 files = Path("../../data").glob("*.csv")
#       5 for file in files:
# ----> 6     df = pd.read_csv(file)
#       7     print(f"{file} {df.columns}")
#
# NameError: name 'pd' is not defined
